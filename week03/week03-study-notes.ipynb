# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r.status_code  # 状态码
# Out:
# 200

# %%
r.headers   # 请求头
# Out:
# {'Server': 'GitHub.com', 'Date': 'Thu, 09 Mar 2023 02:11:54 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"e0c3407a3df79c95dd662819c6fc019eee218b904733a849fd3a380cf8970353"', 'Last-Modified': 'Thu, 09 Mar 2023 02:06:53 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000
# ...

# %%
r.encoding # 页面编码
# Out:
# 'utf-8'

# %%
r.headers['Server']
# Out:
# 'GitHub.com'

# %% [markdown]
# # 页面三中不同数据形态获取
# * 观察text、json、content三种样式区别
# * 思考什么情况下用那种形态

# %%
r.text
# Out:
# '[{"id":"27592477736","type":"PushEvent","actor":{"id":60825784,"login":"predictcrypto","display_login":"predictcrypto","gravatar_id":"","url":"https://api.github.com/users/predictcrypto","avatar_url":"https://avatars.githubusercontent.com/u/60825784?"},"repo":{"id":570543109,"name":"predictcrypto/pins","url":"https://api.github.com/repos/predictcrypto/pins"},"payload":{"repository_id":570543109,"push_id":12876398224,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1f35602a2f8974099f4c159e132b5f389910a487","before":"d4611a68f3d45dc49eadce8ae8a790528b421978","commits":[{"sha":"1f35602a2f8974099f4c159e132b5f389910a487","author":{"email":"60825784+predictcrypto@users.noreply.github.com","name":"predictcrypto"},"message":"update hitBTC_orderbook","distinct":true,"url":"https://api.github.com/repos/predictcrypto/pins/commits/1f35602a2f8974099f4c159e132b5f389910a487"}]},"public":true,"created_at":"2023-03-09T02:06:53Z"},{"id":"27592477757","type":"PushEvent","actor":{"id":62972
# ...

# %%
r.json()
# Out:
# [{'id': '27592477736',
#   'type': 'PushEvent',
#   'actor': {'id': 60825784,
#    'login': 'predictcrypto',
#    'display_login': 'predictcrypto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/predictcrypto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60825784?'},
#   'repo': {'id': 570543109,
#    'name': 'predictcrypto/pins',
#    'url': 'https://api.github.com/repos/predictcrypto/pins'},
#   'payload': {'repository_id': 570543109,
#    'push_id': 12876398224,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1f35602a2f8974099f4c159e132b5f389910a487',
#    'before': 'd4611a68f3d45dc49eadce8ae8a790528b421978',
#    'commits': [{'sha': '1f35602a2f8974099f4c159e132b5f389910a487',
#      'author': {'email': '60825784+predictcrypto@users.noreply.github.com',
#       'name': 'predictcrypto'},
#      'message': 'update hitBTC_orderbook',
#      'distinct': True,
# ...

# %%
r.content
# Out:
# b'[{"id":"27592477736","type":"PushEvent","actor":{"id":60825784,"login":"predictcrypto","display_login":"predictcrypto","gravatar_id":"","url":"https://api.github.com/users/predictcrypto","avatar_url":"https://avatars.githubusercontent.com/u/60825784?"},"repo":{"id":570543109,"name":"predictcrypto/pins","url":"https://api.github.com/repos/predictcrypto/pins"},"payload":{"repository_id":570543109,"push_id":12876398224,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1f35602a2f8974099f4c159e132b5f389910a487","before":"d4611a68f3d45dc49eadce8ae8a790528b421978","commits":[{"sha":"1f35602a2f8974099f4c159e132b5f389910a487","author":{"email":"60825784+predictcrypto@users.noreply.github.com","name":"predictcrypto"},"message":"update hitBTC_orderbook","distinct":true,"url":"https://api.github.com/repos/predictcrypto/pins/commits/1f35602a2f8974099f4c159e132b5f389910a487"}]},"public":true,"created_at":"2023-03-09T02:06:53Z"},{"id":"27592477757","type":"PushEvent","actor":{"id":6297
# ...

# %%
b = requests.get('https://www.bilibili.com/')

# %%
b.status_code
# Out:
# 200

# %%
b.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File E:\Anaconda3\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File E:\Anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
# 通用识别分析


import requests
import json


def main():

    url = "https://aip.baidubce.com/oauth/2.0/token?client_id=CbbzKqW56mcx7X2hUWGHDvT2&client_secret=WHMnGYfqKczuypq8V83PF8uUaywOQ5CD&grant_type=client_credentials"

    payload = ""
    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    print(response.json()['access_token'])


if __name__ == '__main__':
    main()
# Out:
# 24.028383b750fa3f934514c2b3d646840a.2592000.1680925005.282335-31101623

# %%
import base64

'''
通用物体和场景识别
'''

request_url = "https://aip.baidubce.com/rest/2.0/image-classify/v2/advanced_general"
# 二进制方式打开图片文件
f = open('./th.jpg', 'rb')
img = base64.b64encode(f.read())

params = {"image":img,'baike_num':5}
access_token = '24.6b4efd8cf8bcbf4663dc137ac04d41cf.2592000.1680924401.282335-31101623'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'result_num': 5, 'result': [{'keyword': '图画', 'score': 0.08212, 'root': '商品-绘画', 'baike_info': {'baike_url': 'http://baike.baidu.com/item/%E5%9B%BE%E7%94%BB/3357821', 'image_url': 'https://bkimg.cdn.bcebos.com/pic/a8773912b31bb05191a21521387adab44aede031', 'description': '图画，汉语词语，读音是tú huà，意思是绘画。'}}, {'keyword': '植物', 'score': 0.078681, 'root': '自然风景-草原', 'baike_info': {'baike_url': 'http://baike.baidu.com/item/%E6%A4%8D%E7%89%A9/142914', 'image_url': 'https://bkimg.cdn.bcebos.com/pic/f11f3a292df5e0fe2ca26867536034a85edf721a', 'description': '植物(Plants)是生命的主要形态之一，包含了如树木、灌木、藤类、青草、蕨类，及绿藻、地衣等熟悉的生物。植物可以分为种子植物、苔藓植物、蕨类植物等，据估计现存大约有450 000个物种。绿色植物大部分的能源是经由光合作用从太阳光中得到的，温度、湿度、光线、淡水是植物生存的基本需求。被子植物共有六大器官：根、茎、叶、花、果实、种子。绿色植物具有光合作用的能力——借助光能及叶绿素，在酶的催化作用下，利用水、无机盐,二氧化碳进行光合作用，释放氧气，产生葡萄糖等有机物，供植物体利用。'}}, {'keyword': '油画', 'score': 0.054744, 'root': '非自然图像-艺术画', 'baike_info': {'baike_url': 'http://baike.baidu.com/item/%E6%B2%B9%E7%94%BB/68558', 'image_url': 'https://bkimg.cdn.bcebos.com/pic/6c224f4a20a44
# ...

# %%
# 通用识别分析


import requests
import json


def main():

    url = "https://aip.baidubce.com/oauth/2.0/token?client_id=CbbzKqW56mcx7X2hUWGHDvT2&client_secret=WHMnGYfqKczuypq8V83PF8uUaywOQ5CD&grant_type=client_credentials"

    payload = ""
    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    print(response.json()['access_token'])


if __name__ == '__main__':
    main()

import base64

'''
通用物体和场景识别
'''

request_url = "https://aip.baidubce.com/rest/2.0/image-classify/v2/advanced_general"
# 二进制方式打开图片文件
f = open('./th.jpg', 'rb')
img = base64.b64encode(f.read())

params = {"image":img,'baike_num':5}
access_token = '24.6b4efd8cf8bcbf4663dc137ac04d41cf.2592000.1680924401.282335-31101623'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
